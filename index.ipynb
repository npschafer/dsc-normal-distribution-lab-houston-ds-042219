# %% [markdown]
# # The Normal Distribution - Lab

# %% [markdown]
# ## Introduction
# In this lab, you'll learn how to generate random normal distributions in Python. You'll learn how to visualize a histogram and build a density function using the formula.
# ## Objectives
# You will be able to:
# * Generate random normal distributions in python with given parameters
# * Calculate the density function for normal distributions
# * Use seaborn to visualize distributions with histograms and density functions

# %% [markdown]
# ## A quick refresher!
#
# Here's the formula for the normal distribution density function once more:
#
# $$ \large N(x) = \dfrac{1}{\sigma \sqrt {2\pi }}e^{-\dfrac{(x-\mu)^2}{2\sigma^2}}$$
#
# Here,
# - $\mu$ is the mean
# - $\sigma$ is the standard deviation
# - $\pi \approx 3.14159 $
# - $ e \approx 2.71828 $

# %% [markdown]
# ## First generate a normal distribution containing 5000 values with $\mu=14$ and $\sigma = 2.8$

# %%
import numpy as np
import seaborn as sns

mu, sigma = 14, 2.8
n = 5000
s = np.random.normal(mu, sigma, n)
sns.distplot(s)
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Calculate a normalized histogram for this distribution in matplotlib, with bin size = 20
#
# Make sure to get the bin positions and counts for each of the obtained bins. You can use [official documentation](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html) to view input and output options for `plt.hist()`

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(s, density=True,bins=20)
# Out:
# (array([0.00086351, 0.00215877, 0.00647631, 0.01057797, 0.02396235,
#         0.04274364, 0.06627423, 0.09088421, 0.11657357, 0.13233259,
#         0.14204705, 0.12779917, 0.10837024, 0.08462378, 0.06022968,
#         0.03043865, 0.01662253, 0.00885096, 0.00539692, 0.00215877]),
#  array([ 4.46841369,  5.39486725,  6.32132082,  7.24777439,  8.17422796,
#          9.10068152, 10.02713509, 10.95358866, 11.88004222, 12.80649579,
#         13.73294936, 14.65940293, 15.58585649, 16.51231006, 17.43876363,
#         18.36521719, 19.29167076, 20.21812433, 21.14457789, 22.07103146,
#         22.99748503]),
#  <a list of 20 Patch objects>)

# %%
# Calculate a histogram for above data distribution

# %% [markdown]
# ## Use the formula to calculate the density function with $\mu$, $\sigma$ and bin information obtained before

# %%
# Calculate the normal Density function 
density_y = np.histogram(s, density=True,bins=20)[0]
density_x = np.histogram(s, density=True,bins=20)[1]
plt.hist(s, density=True,bins=20)
plt.plot((density_x[1:]+density_x[:len(density)])/2, density_y)

# %% [markdown]
# ## Plot the histogram and density function

# %%
# Plot histogram along with the density function

# %% [markdown]
# ## Visualize the distribution using seaborn and plot the KDE

# %%
sns.distplot(s)
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Use seaborn to plot the histogram with KDE

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to generate random normal distributions in Python using Numpy. You also calculated the density for gaussian distributions using the general formula as well as seaborn's kde. Next, you'll move on an learn how normal distributions are used to answer analytical questions.
